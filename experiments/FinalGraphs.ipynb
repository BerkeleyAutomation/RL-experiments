# %%
% matplotlib inline
import matplotlib
plt = matplotlib.pyplot
import run_transfer as rt
import rlpy.Tools.run

# %%
##Below are parameters for one possible implementation of basic version; converged by 400 episodes though
# agent_eps=0.2, env_noise=0.1, episodeCap=30, 
# def terminal_reward(self): return (2 * self.GOAL_REWARD - self.steps) 
#self.GOAL_REWARD = episodeCap 
#self.PIT_REWARD = -self.GOAL_REWARD / 2
#  step_reward=-0.1,

# %%
% matplotlib inline
def plot_single_returns(results):
    plt.plot(results['learning_episode'], results['return'])
    plt.title("Return vs Rollouts")

# %%
res_default_map = rt.run_single_map()
plot_single_returns(res_default_map)

# %%
res_1 = rt.run_single_map("9x9-2PathR1.txt")
plot_single_returns(res_1)

# %%
# %matplotlib inline
import mer_variables as mv

# %%
n = mv.load_variable("agent_eps")
y = mv.plot_avg_sem(n)

# %%
n_1 = mv.load_variable("env_noise")
y = mv.plot_avg_sem(n_1)

# %%
n_2 = mv.load_variable("door_reward")
y = mv.plot_avg_sem(n_2, xscale="log")

# %%
n_3 = mv.load_variable("step_reward")
y= mv.plot_avg_sem(n_3)
